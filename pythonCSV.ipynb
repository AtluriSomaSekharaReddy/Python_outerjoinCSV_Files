# %%
import pandas as pd

# %%
data_1=pd.read_csv("emp_core.csv")

# %%
data_2=pd.read_csv("emp_contact.csv")

# %%
final=pd.merge(data_1,data_2,how="outer",on="EMPLOYEE_ID")

# %%
final
# Out:
#     EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER
# 0           198       Donald     OConnell  DOCONNEL  650.507.9833
# 1           199      Douglas        Grant    DGRANT  650.507.9844
# 2           200     Jennifer       Whalen   JWHALEN  515.123.4444
# 3           201      Michael    Hartstein  MHARTSTE  515.123.5555
# 4           202          Pat          Fay      PFAY  603.123.6666
# 5           203        Susan       Mavris   SMAVRIS  515.123.7777
# 6           204      Hermann         Baer     HBAER  515.123.8888
# 7           205      Shelley      Higgins  SHIGGINS  515.123.8080
# 8           206      William        Gietz    WGIETZ  515.123.8181
# 9           100       Steven         King     SKING  515.123.4567
# 10          101        Neena      Kochhar  NKOCHHAR  515.123.4568
# 11          102          Lex      De Haan   LDEHAAN  515.123.4569
# 12          103    Alexander       Hunold   AHUNOLD  590.423.4567
# ...

# %% [markdown]
# # 2nd Approch

# %%
import csv
records1=[]
with open('emp_core.csv', 'r') as f:
    for line in f:
        records1.append(line.split(','))

records2=[]
with open('emp_contact.csv', 'r') as f:
    for line in f:
        records2.append(line.split(','))
records2[0][0]="ID"
# print(records2)
final_2=[]
# final_2.append(["EMPLOYEE_ID","FIRST_NAME","LAST_NAME","EMAIL","PHONE_NUMBER"])
for (EMPLOYEE_ID, FIRST_NAME, LAST_NAME) in records1:
    for (ID, EMAIL, PHONE_NUMBER) in records2:
        if EMPLOYEE_ID == ID:
            final_2.append([EMPLOYEE_ID,FIRST_NAME,LAST_NAME[:len(LAST_NAME)-1],EMAIL,PHONE_NUMBER[:len(PHONE_NUMBER)-1]])
    
a=pd.DataFrame(final_2,columns=["EMPLOYEE_ID","FIRST_NAME","LAST_NAME","EMAIL","PHONE_NUMBER"])

# %%
a
# Out:
#    EMPLOYEE_ID   FIRST_NAME    LAST_NAME     EMAIL  PHONE_NUMBER
# 0          198       Donald     OConnell  DOCONNEL  650.507.9833
# 1          199      Douglas        Grant    DGRANT  650.507.9844
# 2          200     Jennifer       Whalen   JWHALEN  515.123.4444
# 3          201      Michael    Hartstein  MHARTSTE  515.123.5555
# 4          202          Pat          Fay      PFAY  603.123.6666
# 5          203        Susan       Mavris   SMAVRIS  515.123.7777
# 6          204      Hermann         Baer     HBAER  515.123.8888
# 7          205      Shelley      Higgins  SHIGGINS  515.123.8080
# 8          206      William        Gietz    WGIETZ  515.123.8181
# 9          100       Steven         King     SKING  515.123.4567
# 10         101        Neena      Kochhar  NKOCHHAR  515.123.4568
# 11         102          Lex      De Haan   LDEHAAN  515.123.4569
# 12         103    Alexander       Hunold   AHUNOLD  590.423.4567
# ...
